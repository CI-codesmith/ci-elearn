# %% [markdown]
# # MICROPROJECT ADVANCED 3: Time Series Forecasting
#
# **Name:** [YOUR NAME]
# **Difficulty:** Advanced
# **Duration:** 3 weeks

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# ## Phase 1: Foundation
#
# [Start your implementation here]

# %% [markdown]
# ## Summary
#
# Advanced learnings:
# 1. [Learning 1]
# 2. [Learning 2]
# 3. [Learning 3]
