# %% [markdown]
# # MICROPROJECT 1.1: Introduction to Machine Learning & Python Basics
#
# **Your Name:** [YOUR NAME HERE]
# **Date:** [DATE]
# **Unit:** 1 - Introduction to Machine Learning

# %% [markdown]
# ## Task 1: What is Machine Learning?
#
# Write a short explanation (3-5 sentences) of what machine learning is and how it differs from traditional programming.
#
# **Your Answer:**
#
# [WRITE YOUR EXPLANATION HERE]

# %% [markdown]
# ## Task 2: Types of Machine Learning
#
# Describe the three main types of machine learning with real-world examples.
#
# ### 2.1 Supervised Learning
# **Definition:**
#
# [WRITE HERE]
#
# **Example:**
#
# [WRITE HERE]
#
# ### 2.2 Unsupervised Learning
# **Definition:**
#
# [WRITE HERE]
#
# **Example:**
#
# [WRITE HERE]
#
# ### 2.3 Reinforcement Learning
# **Definition:**
#
# [WRITE HERE]
#
# **Example:**
#
# [WRITE HERE]

# %% [markdown]
# ## Task 3: Real-World ML Applications
#
# Describe three real-world applications of Machine Learning.
#
# ### Application 1
# **Name:** [APPLICATION NAME]
#
# **Description:**
#
# [DESCRIBE HOW ML IS USED]
#
# **Industry:** [INDUSTRY]
#
# ### Application 2
# **Name:** [APPLICATION NAME]
#
# **Description:**
#
# [DESCRIBE HOW ML IS USED]
#
# **Industry:** [INDUSTRY]
#
# ### Application 3
# **Name:** [APPLICATION NAME]
#
# **Description:**
#
# [DESCRIBE HOW ML IS USED]
#
# **Industry:** [INDUSTRY]

# %% [markdown]
# ## Task 4: Python Basics for ML
#
# Write Python code for the following operations.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %% [markdown]
# ### 4.1 Create Lists and NumPy Arrays

# %%
# Create a Python list
# [YOUR CODE HERE]

# Create a NumPy array
# [YOUR CODE HERE]

# Show the difference
# [YOUR CODE HERE]

# %% [markdown]
# ### 4.2 Load Iris Dataset

# %%
# Load the Iris dataset
# [YOUR CODE HERE]

# Create a DataFrame
# [YOUR CODE HERE]

# Display first 5 rows
# [YOUR CODE HERE]

# Show dataset shape
# [YOUR CODE HERE]

# Show column names
# [YOUR CODE HERE]

# %% [markdown]
# ### 4.3 Create a Simple Plot

# %%
# Create x and y values
# [YOUR CODE HERE]

# Plot the data
# [YOUR CODE HERE]

# Add labels and title
# [YOUR CODE HERE]

# Display the plot
# [YOUR CODE HERE]

# %% [markdown]
# ## Task 5: ML Libraries Overview
#
# Describe the purpose of each library in your own words.
#
# ### NumPy
# **What it does:**
#
# [WRITE HERE]
#
# **Example use:**
#
# [WRITE HERE]
#
# **Why important for ML:**
#
# [WRITE HERE]
#
# ### Pandas
# **What it does:**
#
# [WRITE HERE]
#
# **Example use:**
#
# [WRITE HERE]
#
# **Why important for ML:**
#
# [WRITE HERE]
#
# ### Matplotlib
# **What it does:**
#
# [WRITE HERE]
#
# **Example use:**
#
# [WRITE HERE]
#
# **Why important for ML:**
#
# [WRITE HERE]
#
# ### Scikit-learn
# **What it does:**
#
# [WRITE HERE]
#
# **Example use:**
#
# [WRITE HERE]
#
# **Why important for ML:**
#
# [WRITE HERE]

# %% [markdown]
# ## Summary
#
# In this microproject, I learned:
# 1. [LEARNING 1]
# 2. [LEARNING 2]
# 3. [LEARNING 3]
# 4. [LEARNING 4]
