# %% [markdown]
# # Practical 1: Installation of IDE with Necessary Libraries## Practical Information| Attribute | Details ||-----------|---------|| **Practical Number** | 1 || **Title** | Installation of IDE with Necessary Libraries || **Duration** | 2 Hours || **Course Outcomes (COs)** | CO1 || **Description** | Set up Python development environment with essential ML libraries and verify installation. |## Key Topics Covered- Python setup- Virtual environment- ML libraries- Jupyter Notebook- Testing installation---## Instructions for Students1. **Complete all tasks** outlined in this practical2. **Write your code** in the cells provided below3. **Add comments** to explain your code4. **Include proper output** (prints, visualizations, etc.)5. **Submit your completed notebook** before the deadline---## Your Work Starts HereUse the cell(s) below to write your implementation:

# %%
# Practical 1: Installation of IDE with Necessary Libraries
# Write your implementation here

# %%
# Additional code cell

# %%
# Additional code cell
